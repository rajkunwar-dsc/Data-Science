# %%
import pandas as pd
import numpy as np

banks = pd.read_csv('./data/banklist.csv')
banks
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# 5                               Harvest Community Bank          Pennsville
# 6                                          Allied Bank            Mulberry
# 7                         The Woodbury Banking Company            Woodbury
# 8                               First CornerStone Bank     King of Prussia
# 9                                   Trust Company Bank             Memphis
# 10                          North Milwaukee State Bank           Milwaukee
# ...

# %%
banks.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %%
banks['ST'].count()
# Out:
# 551

# %%
list(banks['ST'].unique())
# Out:
# ['IL',
#  'WI',
#  'LA',
#  'UT',
#  'NJ',
#  'AR',
#  'GA',
#  'PA',
#  'TN',
#  'WA',
#  'CO',
#  'PR',
#  'FL',
#  'MN',
#  'CA',
#  'MD',
#  'OK',
#  'OH',
#  'SC',
#  'VA',
#  'ID',
#  'TX',
#  'CT',
#  'AZ',
#  'NV',
#  'NC',
#  'KY',
#  'MO',
#  'KS',
#  'AL',
#  'MI',
#  'IN',
#  'IA',
#  'NE',
#  'MS',
#  'NM',
#  'OR',
#  'NY',
#  'MA',
#  'SD',
#  'WY',
#  'WV',
#  'NH',
#  'HI']

# %%
#banks.loc[banks['ST'].value_counts().head()]
#grouped = banks.groupby(['ST'])
#banks2 = banks.apply(lambda x:x)
#banks2.head()


banks['ST'].value_counts().head()
# Out:
# GA    93
# FL    75
# IL    67
# CA    41
# MN    23
# Name: ST, dtype: int64

# %%
banks['Acquiring Institution'].value_counts().head()
# Out:
# No Acquirer                            31
# State Bank and Trust Company           12
# First-Citizens Bank & Trust Company    11
# Ameris Bank                            10
# U.S. Bank N.A.                          9
# Name: Acquiring Institution, dtype: int64

# %%
banks[(banks['Acquiring Institution']=='State Bank of Texas') & (banks['ST']=='TX')]
# Out:
#                           Bank Name    City  ST   CERT Acquiring Institution  \
# 450  Millennium State Bank of Texas  Dallas  TX  57667   State Bank of Texas
#
#     Closing Date Updated Date
# 450     2-Jul-09    26-Oct-12

# %%
#banks.where(banks['Acquiring Institution']=='State Bank of Texas').dropna().groupby('Acquiring Institution')
#banks['acquired'] = banks['Acquiring Institution'].apply(lambda x : 1 if x =='State Bank of Texas' else 0)

banks2 = banks[(banks['Acquiring Institution']=='State Bank of Texas')]
banks2
# Out:
#                                  Bank Name     City  ST   CERT  \
# 4            Seaway Bank and Trust Company  Chicago  IL  19328
# 21   The National Republic Bank of Chicago  Chicago  IL    916
# 450         Millennium State Bank of Texas   Dallas  TX  57667
#
#     Acquiring Institution Closing Date Updated Date
# 4     State Bank of Texas    27-Jan-17    18-May-17
# 21    State Bank of Texas    24-Oct-14     6-Jan-16
# 450   State Bank of Texas     2-Jul-09    26-Oct-12

# %%
banks2[(banks2['ST']=='TX')]
# Out:
#                           Bank Name    City  ST   CERT Acquiring Institution  \
# 450  Millennium State Bank of Texas  Dallas  TX  57667   State Bank of Texas
#
#     Closing Date Updated Date
# 450     2-Jul-09    26-Oct-12

# %%
banks3 = banks[(banks['ST']=='CA')]
banks3['City'].value_counts().index[0]
# Out:
# 'Los Angeles'

# %%
banks[~(banks['Bank Name'].str.contains('Bank'))]
# Out:
#                                              Bank Name           City  ST  \
# 22                                      NBRS Financial     Rising Sun  MD
# 74   Second Federal Savings and Loan Association of...        Chicago  IL
# 101                            Home Savings of America   Little Falls  MN
# 222                       First Arizona Savings, A FSB     Scottsdale  AZ
# 248              Imperial Savings and Loan Association   Martinsville  VA
# 300                                         CF Bancorp     Port Huron  MI
# 301                            Westernbank Puerto Rico       Mayaguez  PR
# 303                                           Eurobank       San Juan  PR
# 423                                              ebank        Atlanta  GA
# 428        Dwelling House Savings and Loan Association     Pittsburgh  PA
# 496                                       Suburban FSB        Crofton  MD
# 505                              Downey Savings & Loan  Newport Beach  CA
# ...

# %%
banks['Bank Name'] = banks['Bank Name'].str.upper() 
banks[(banks['Bank Name'].str.startswith('S'))]
# Out:
#                                              Bank Name              City  ST  \
# 4                        SEAWAY BANK AND TRUST COMPANY           Chicago  IL
# 28                         SLAVIE FEDERAL SAVINGS BANK           Bel Air  MD
# 34                                        SYRINGA BANK             Boise  ID
# 41                             SUNRISE BANK OF ARIZONA           Phoenix  AZ
# 49                                        SUNRISE BANK          Valdosta  GA
# 74   SECOND FEDERAL SAVINGS AND LOAN ASSOCIATION OF...           Chicago  IL
# 82                              SECURITY EXCHANGE BANK          Marietta  GA
# 89                 SECURITY BANK, NATIONAL ASSOCIATION  North Lauderdale  FL
# 103                                           SCB BANK       Shelbyville  IN
# 117                                      SUNFIRST BANK      Saint George  UT
# 128                                  SUN SECURITY BANK         Ellington  MO
# ...

# %%
banks[(banks['CERT']>2000)].shape[0]
# Out:
# 536

# %%
banks['Bank Name'] = banks['Bank Name'].str.strip(' ') 
banks[(banks['Bank Name'].str.count(' ')==1)]
# Out:
#                Bank Name                City  ST   CERT  \
# 3          PROFICIO BANK  Cottonwood Heights  UT  35495
# 6            ALLIED BANK            Mulberry  AR     91
# 13          PREMIER BANK              Denver  CO  34112
# 14        EDGEBROOK BANK             Chicago  IL  57772
# 15            DORAL BANK            San Juan  PR  32102
# 22        NBRS FINANCIAL          Rising Sun  MD   4862
# 26           VALLEY BANK     Fort Lauderdale  FL  21793
# 27           VALLEY BANK              Moline  IL  10450
# 30     AZTECAMERICA BANK              Berwyn  IL  57866
# 34          SYRINGA BANK               Boise  ID  34296
# 49          SUNRISE BANK            Valdosta  GA  58185
# 52          PARKWAY BANK              Lenoir  NC  57158
# 57         FRONTIER BANK            LaGrange  GA  16431
# 58         COVENANT BANK             Chicago  IL  22476
# 65             NOVA BANK              Berwyn  PA  27148
# 66            EXCEL BANK             Sedalia  MO  19189
# ...

# %%
banks['Closing Date'] = pd.to_datetime(banks['Closing Date'])
banks[(banks['Closing Date'].dt.year == 2008)]
# Out:
#                                              Bank Name           City  ST  \
# 501                               SANDERSON STATE BANK      Sanderson  TX
# 502                                   HAVEN TRUST BANK         Duluth  GA
# 503                       FIRST GEORGIA COMMUNITY BANK        Jackson  GA
# 504                                   PFF BANK & TRUST         Pomona  CA
# 505                              DOWNEY SAVINGS & LOAN  Newport Beach  CA
# 506                                     COMMUNITY BANK     Loganville  GA
# 507                              SECURITY PACIFIC BANK    Los Angeles  CA
# 508                                 FRANKLIN BANK, SSB        Houston  TX
# 509                                       FREEDOM BANK      Bradenton  FL
# 510                                 ALPHA BANK & TRUST     Alpharetta  GA
# 511                                      MERIDIAN BANK         Eldred  IL
# 512                                   MAIN STREET BANK     Northville  MI
# ...
